# %%
# What is Pandas?
# Python library used for working with structured data sets (tables). It has functions for analyzing, cleaning, exploring, and manipulating data. Similar to data tables in SQL and Excel.

# %%
# install pandas

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# import pandas
import pandas as pd

# %%
pd.__version__ # check installed pandas version
# Out:
# '3.0.2'

# %%
# What is Dataframe?
# It's a structured data constructed with rows and columns, similar to a SQL tables or Excel tables

# %%
# 1 Create Dataframe

# %%
# using a List
df = pd.DataFrame([11,22,33], columns=['Col_Name'])
print(df)
# Out:
#    Col_Name
# 0        11
# 1        22
# 2        33

# %%
print(type(df)) # check data type
# Out:
# <class 'pandas.DataFrame'>

# %%
# using Dictionary of Lists
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16,17,18,19],
    'Salary': [90000, 70000, 50000, 30000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
print(type(df))
# Out:
# <class 'pandas.DataFrame'>

# %%
 # 2 Basic Dataframe Understanding

# %%
df.head(2) # top rows
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000

# %%
df.tail(2) # last rows
# Out:
#       Name  Age  Salary
# 2   Lalita   18   50000
# 3  Rishabh   19   30000

# %%
df.shape # returns a tuple containing the shape of the DataFrame - rows & columns
# Out:
# (4, 3)

# %%
df.columns # list of column names in a dataframe
# Out:
# Index(['Name', 'Age', 'Salary'], dtype='str')

# %%
df.rename(columns={'Salary': 'Monthly_Salary'}, inplace=True) # rename column name/s

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df.info()  # info method prints information about the DataFrame
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 3 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Name            4 non-null      str
#  1   Age             4 non-null      int64
#  2   Monthly_Salary  4 non-null      int64
# dtypes: int64(2), str(1)
# memory usage: 228.0 bytes

# %%
df.describe() # describe method generates descriptive statistics of DataFrame, only for numerical-value columns
# Out:
#              Age  Monthly_Salary
# count   4.000000        4.000000
# mean   17.500000    60000.000000
# std     1.290994    25819.888975
# min    16.000000    30000.000000
# 25%    16.750000    45000.000000
# 50%    17.500000    60000.000000
# 75%    18.250000    75000.000000
# max    19.000000    90000.000000

# %%
# 3 Save and Load data from csv

# %%
df.to_csv('Test_data.csv', index=False) # export data frame

# %%
load_df = pd.read_csv('Test_data.csv') # import dataframe
load_df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
# 4. Rows and Columns - Selection

# %%
# select column
df[['Name']]  # single column
df[['Name', 'Monthly_Salary']]
# Out:
#        Name  Monthly_Salary
# 0    Madhav           90000
# 1  Vishakha           70000
# 2    Lalita           50000
# 3   Rishabh           30000

# %%
 # select rows
# loc - index name based
df.loc[df.Name == 'Madhav']
df.loc[(df.Name=='Madhav') & (df.Monthly_Salary>=50000)]
# Out:
#      Name  Age  Monthly_Salary
# 0  Madhav   16           90000

# %%
df.loc[0:2]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000

# %%
# iloc - index-value based
# df.iloc[0]
df.iloc[0:2] # [start:stop:step]
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000

# %%
# 5. Filter dataframe

# %%
df
# Out:
#        Name  Age  Monthly_Salary
# 0    Madhav   16           90000
# 1  Vishakha   17           70000
# 2    Lalita   18           50000
# 3   Rishabh   19           30000

# %%
df['Age'] > 15
# Out:
# 0    True
# 1    True
# 2    True
# 3    True
# Name: Age, dtype: bool

# %%
df_age_filter = df[df['Age'] >=18]

# %%
df_age_filter
# Out:
#       Name  Age  Monthly_Salary
# 2   Lalita   18           50000
# 3  Rishabh   19           30000

# %%
df[(df['Age'] >= 18) & (df['Monthly_Salary'] >= 50000)]
# Out:
#      Name  Age  Monthly_Salary
# 2  Lalita   18           50000

# %%
df.where(df['Age'] >= 18)
# Out:
#       Name   Age  Monthly_Salary
# 0      NaN   NaN             NaN
# 1      NaN   NaN             NaN
# 2   Lalita  18.0         50000.0
# 3  Rishabh  19.0         30000.0

# %%
df.where(df['Age'] >= 18, other = 'Not Eligible')
# Out:
#            Name           Age Monthly_Salary
# 0  Not Eligible  Not Eligible   Not Eligible
# 1  Not Eligible  Not Eligible   Not Eligible
# 2        Lalita            18          50000
# 3       Rishabh            19          30000

# %%
import pandas as pd

# %%
# 6. Rows and Columns - Operation (Add, Update, Delete)

# %%
# !pip install pandas
# Out:
# Requirement already satisfied: pandas in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (3.0.2)
# Requirement already satisfied: numpy>=2.3.3 in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.4.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from pandas) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\sa776\appdata\local\programs\python\python314\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# [notice] A new release of pip is available: 25.3 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %%
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16,17,18,19],
    'Salary': [90000, 70000, 50000, 30000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
# add new column
df['Team'] = ['CEO', 'HR', 'CTO', 'DA']
df
# Out:
#        Name  Age  Salary Team
# 0    Madhav   16   90000  CEO
# 1  Vishakha   17   70000   HR
# 2    Lalita   18   50000  CTO
# 3   Rishabh   19   30000   DA

# %%
df['Bonus'] = df['Salary'] * 0.2
df
# Out:
#        Name  Age  Salary Team    Bonus
# 0    Madhav   16   90000  CEO  18000.0
# 1  Vishakha   17   70000   HR  14000.0
# 2    Lalita   18   50000  CTO  10000.0
# 3   Rishabh   19   30000   DA   6000.0

# %%
# add new row
df.loc[len(df)] = ['Ayush', 20, 95000, 'IT', 20000]
df
# Out:
#        Name  Age  Salary Team    Bonus
# 0    Madhav   16   90000  CEO  18000.0
# 1  Vishakha   17   70000   HR  14000.0
# 2    Lalita   18   50000  CTO  10000.0
# 3   Rishabh   19   30000   DA   6000.0
# 4     Ayush   20   95000   IT  20000.0

# %%
len(df)
# Out:
# 5

# %%
# Update value - using index name
df.loc[0, 'Salary'] = 85000
df
# Out:
#        Name  Age  Salary Team    Bonus
# 0    Madhav   16   85000  CEO  18000.0
# 1  Vishakha   17   70000   HR  14000.0
# 2    Lalita   18   50000  CTO  10000.0
# 3   Rishabh   19   30000   DA   6000.0
# 4     Ayush   20   95000   IT  20000.0

# %%
# Update value - using column value
df.loc[df.Name == 'Madhav', 'Salary'] = 90000
df
# Out:
#        Name  Age  Salary Team    Bonus
# 0    Madhav   16   90000  CEO  18000.0
# 1  Vishakha   17   70000   HR  14000.0
# 2    Lalita   18   50000  CTO  10000.0
# 3   Rishabh   19   30000   DA   6000.0
# 4     Ayush   20   95000   IT  20000.0

# %%
# delete value - row and column values

# %%
df = df.drop(df[df.Name == 'Lalita'].index) #drop row, axis =0

# %%
df.drop('Age', axis=1, inplace=True)  # drop column

# %%
df
# Out:
#        Name  Salary Team
# 0    Madhav   90000  CEO
# 1  Vishakha   70000   HR
# 3   Rishabh   30000   DA
# 4     Ayush   95000   IT

# %%
# df.drop(['Name', 'Team'], axis=1) # delete multiple columns

# %%
df
# Out:
#        Name  Salary Team
# 0    Madhav   90000  CEO
# 1  Vishakha   70000   HR
# 3   Rishabh   30000   DA
# 4     Ayush   95000   IT

# %%
# Sort value
df.sort_values('Salary') # ascending order, by default
# Out:
#        Name  Salary Team
# 3   Rishabh   30000   DA
# 1  Vishakha   70000   HR
# 0    Madhav   90000  CEO
# 4     Ayush   95000   IT

# %%
df.sort_values('Salary', ascending=False) # descending order
# Out:
#        Name  Salary Team
# 4     Ayush   95000   IT
# 0    Madhav   90000  CEO
# 1  Vishakha   70000   HR
# 3   Rishabh   30000   DA

# %%
# 7. Working with date value

# %%
df['DOJ'] = ['2026-01-01', '2026-01-15', '2026-03-28', '2026-06-01']
df
# Out:
#        Name  Salary Team         DOJ
# 0    Madhav   90000  CEO  2026-01-01
# 1  Vishakha   70000   HR  2026-01-15
# 3   Rishabh   30000   DA  2026-03-28
# 4     Ayush   95000   IT  2026-06-01

# %%
df['DOJ'].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
df['DOJ'] = pd.to_datetime(df['DOJ'])

# %%
df['DOJ'].dtype
# Out:
# dtype('<M8[us]')

# %%
df['DOJ'].dt.year
# Out:
# 0    2026
# 1    2026
# 3    2026
# 4    2026
# Name: DOJ, dtype: int32

# %%
# extract year, month, week, day
df['DOJ'].dt.year
df['DOJ'].dt.month
df['DOJ'].dt.month
df['DOJ'].dt.day_name()
# Out:
# 0    Thursday
# 1    Thursday
# 3    Saturday
# 4      Monday
# Name: DOJ, dtype: str

# %%
df['DOJ'] + pd.Timedelta(days=90) # no. of days adding , subtracting
# Out:
# 0   2026-04-01
# 1   2026-04-15
# 3   2026-06-26
# 4   2026-08-30
# Name: DOJ, dtype: datetime64[us]

# %%
df
# Out:
#        Name  Salary Team        DOJ
# 0    Madhav   90000  CEO 2026-01-01
# 1  Vishakha   70000   HR 2026-01-15
# 3   Rishabh   30000   DA 2026-03-28
# 4     Ayush   95000   IT 2026-06-01

# %%
# 8. Handling missing values

# %%
df
# Out:
#        Name  Salary Team        DOJ
# 0    Madhav   90000  CEO 2026-01-01
# 1  Vishakha   70000   HR 2026-01-15
# 3   Rishabh   30000   DA 2026-03-28
# 4     Ayush   95000   IT 2026-06-01

# %%
df.isnull()
# Out:
#     Name  Salary   Team    DOJ
# 0  False   False  False  False
# 1  False   False  False  False
# 3  False   False  False  False
# 4  False   False  False  False

# %%
import pandas as pd

# %%
data = {
    'Name': ['Madhav', 'Vishakha', 'Lalita', 'Rishabh'],
    'Age': [16,17,18,19],
    'Salary': [90000, 70000, 50000, 30000]
}

# %%
df = pd.DataFrame(data)
print(df)
# Out:
#        Name  Age  Salary
# 0    Madhav   16   90000
# 1  Vishakha   17   70000
# 2    Lalita   18   50000
# 3   Rishabh   19   30000

# %%
df['Bonus'] = df['Salary'] * 0.2
df
# Out:
#        Name  Age  Salary    Bonus
# 0    Madhav   16   90000  18000.0
# 1  Vishakha   17   70000  14000.0
# 2    Lalita   18   50000  10000.0
# 3   Rishabh   19   30000   6000.0

# %%
df.loc[len(df)] = ['Ayush', 20, 95000,  20000]
df
# Out:
#        Name  Age  Salary    Bonus
# 0    Madhav   16   90000  18000.0
# 1  Vishakha   17   70000  14000.0
# 2    Lalita   18   50000  10000.0
# 3   Rishabh   19   30000   6000.0
# 4     Ayush   20   95000  20000.0

# %%
df['DOJ'] = ['2026-01-01', '2026-01-15', '2026-03-28', '2026-04-21',  '2026-06-01']
df
# Out:
#        Name  Age  Salary    Bonus         DOJ
# 0    Madhav   16   90000  18000.0  2026-01-01
# 1  Vishakha   17   70000  14000.0  2026-01-15
# 2    Lalita   18   50000  10000.0  2026-03-28
# 3   Rishabh   19   30000   6000.0  2026-04-21
# 4     Ayush   20   95000  20000.0  2026-06-01

# %%
import numpy as np

# %%
df.loc[df.Name=='Rishabh', 'Salary'] = np.nan

# %%
df
# Out:
#        Name  Age   Salary    Bonus         DOJ
# 0    Madhav   16  90000.0  18000.0  2026-01-01
# 1  Vishakha   17  70000.0  14000.0  2026-01-15
# 2    Lalita   18  50000.0  10000.0  2026-03-28
# 3   Rishabh   19      NaN   6000.0  2026-04-21
# 4     Ayush   20  95000.0  20000.0  2026-06-01

# %%
df.isnull()
# Out:
#     Name    Age  Salary  Bonus    DOJ
# 0  False  False   False  False  False
# 1  False  False   False  False  False
# 2  False  False   False  False  False
# 3  False  False    True  False  False
# 4  False  False   False  False  False

# %%
df.isnull().sum()
# Out:
# Name      0
# Age       0
# Salary    1
# Bonus     0
# DOJ       0
# dtype: int64

# %%
df.fillna(4000)
# Out:
#        Name  Age   Salary    Bonus         DOJ
# 0    Madhav   16  90000.0  18000.0  2026-01-01
# 1  Vishakha   17  70000.0  14000.0  2026-01-15
# 2    Lalita   18  50000.0  10000.0  2026-03-28
# 3   Rishabh   19   4000.0   6000.0  2026-04-21
# 4     Ayush   20  95000.0  20000.0  2026-06-01

# %%
df['Team'] = ['CEO', 'HR', 'CTO', 'DA', 'IT']
df
# Out:
#        Name  Age   Salary    Bonus         DOJ Team
# 0    Madhav   16  90000.0  18000.0  2026-01-01  CEO
# 1  Vishakha   17  70000.0  14000.0  2026-01-15   HR
# 2    Lalita   18  50000.0  10000.0  2026-03-28  CTO
# 3   Rishabh   19      NaN   6000.0  2026-04-21   DA
# 4     Ayush   20  95000.0  20000.0  2026-06-01   IT

# %%
# 9. Aggregation and group by

# %%
df['Team'].value_counts()
# Out:
# Team
# CEO    1
# HR     1
# CTO    1
# DA     1
# IT     1
# Name: count, dtype: int64

# %%
df[df['Team'] =='HR'].value_counts() # frequency of values in Team column
# Out:
# Name      Age  Salary   Bonus    DOJ         Team
# Vishakha  17   70000.0  14000.0  2026-01-15  HR      1
# Name: count, dtype: int64

# %%
df.groupby('Team')['Salary'].sum()  # aggregation based on group by
# Out:
# Team
# CEO    90000.0
# CTO    50000.0
# DA         0.0
# HR     70000.0
# IT     95000.0
# Name: Salary, dtype: float64

# %%
df.groupby('Team').agg({'Salary': 'mean', 'Name': 'count'})
# Out:
#        Salary  Name
# Team
# CEO   90000.0     1
# CTO   50000.0     1
# DA        NaN     1
# HR    70000.0     1
# IT    95000.0     1

# %%
# 10. Concatenate and Merge Dataframe(JOINS)

# %%
df1 = pd.DataFrame({'ID':[1,2,3], 'Name':['A', 'B', 'C']})
df1
# Out:
#    ID Name
# 0   1    A
# 1   2    B
# 2   3    C

# %%
df2 = pd.DataFrame({'ID':[1,2,2,4], 'Score':[88,96,77,79]})
df2
# Out:
#    ID  Score
# 0   1     88
# 1   2     96
# 2   2     77
# 3   4     79

# %%
pd.concat([df1, df2], axis=0) # vertical / row level / top on top
# Out:
#    ID Name  Score
# 0   1    A    NaN
# 1   2    B    NaN
# 2   3    C    NaN
# 0   1  NaN   88.0
# 1   2  NaN   96.0
# 2   2  NaN   77.0
# 3   4  NaN   79.0

# %%
pd.concat([df1, df2], axis=1) # horizontal / column level / side on side
# Out:
#     ID Name  ID  Score
# 0  1.0    A   1     88
# 1  2.0    B   2     96
# 2  3.0    C   2     77
# 3  NaN  NaN   4     79

# %%
# merge = join

# %%
pd.merge(df1, df2, how='inner', on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
pd.merge(df1, df2, how='inner', left_on='ID', right_on='ID')
# Out:
#    ID Name  Score
# 0   1    A     88
# 1   2    B     96
# 2   2    B     77

# %%
# 11. AI and ChatGPT

# %%
df
# Out:
#        Name  Age   Salary    Bonus         DOJ Team
# 0    Madhav   16  90000.0  18000.0  2026-01-01  CEO
# 1  Vishakha   17  70000.0  14000.0  2026-01-15   HR
# 2    Lalita   18  50000.0  10000.0  2026-03-28  CTO
# 3   Rishabh   19      NaN   6000.0  2026-04-21   DA
# 4     Ayush   20  95000.0  20000.0  2026-06-01   IT

# %%
# Prompt to filter salary > 70000 and January employees

# %%
# Method-1: basic filter
df[(df['Month'] == 1) & (df['Salary'] >= 70000)]

# %%
# Method-2: query method
df.query("Month == 1 and Salary >= 70000")
